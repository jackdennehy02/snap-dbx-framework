# %%
from unity_catalog_manager import UnityManager
um = UnityManager(spark, catalog='snap_dbx')

um.create_container('catalog' , 'snap_dbx')
um.create_container('schema', '01_bronze')
um.create_container('schema', '02_silver')
um.create_container('schema', '03_gold')
um.create_container('volume', 'snap_dbx.01_bronze.landing')
